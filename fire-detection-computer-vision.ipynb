# %% [markdown]
# <a href="https://www.kaggle.com/code/mercurial17/fire-detection-computer-vision?scriptVersionId=123426644" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## OVERVIEW
# ---
# * Image Preprocessing with OpenCV
#     * Masking
#     * Segmentation
#     * Image Sharpening
# * Transfer Learning with Keras Pretrained Model
# * Feature Extraction
# * Deep Learning Model to Classify the Images

# %%
import datetime as dt
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set_style('whitegrid')


import os
from keras.applications import xception
from keras.preprocessing import image
from mpl_toolkits.axes_grid1 import ImageGrid
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import cv2
from scipy.stats import uniform

from tqdm import tqdm
from glob import glob


from keras.models import Model, Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, Masking
from keras.utils import np_utils, to_categorical



from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#copying the pretrained models to the cache directory
cache_dir = os.path.expanduser(os.path.join('~', '.keras'))
if not os.path.exists(cache_dir):
    os.makedirs(cache_dir)
models_dir = os.path.join(cache_dir, 'models')
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

#copy the Xception models
# !cp ../input/keras-pretrained-models/xception* ~/.keras/models/
#show
# !ls ~/.keras/models
# Out:
# xception_weights_tf_dim_ordering_tf_kernels.h5
# xception_weights_tf_dim_ordering_tf_kernels_notop.h5

# %%
base_folder = '../input/fire-dataset'
data_folder = '../input/fire-dataset/fire_dataset'
train_data_folder = '../input/fire-dataset/fire_dataset/fire_images'
test_date_folder  = '../input/fire-dataset/fire_dataset/non_fire_images'

categories = ['fire_images', 'non_fire_images']
len_categories = len(categories)

# %%
image_count = {}
train_data = []

for i , category in tqdm(enumerate(categories)):
    class_folder = os.path.join(data_folder, category)
    label = category
    image_count[category] = []
    
    for path in os.listdir(os.path.join(class_folder)):
        image_count[category].append(category)
        train_data.append(['{}/{}'.format(category, path), i, category])
# Out:
# 2it [00:00,  9.44it/s]

# %%
#show image count
for key, value in image_count.items():
    print('{0} -> {1}'.format(key, len(value)))
# Out:
# fire_images -> 755
# non_fire_images -> 244

# %%
#create a dataframe
df = pd.DataFrame(train_data, columns=['file', 'id', 'label'])
df.shape
df.head()
# Out:
# (999, 3)
#                        file  id        label
# 0  fire_images/fire.743.png   0  fire_images
# 1  fire_images/fire.717.png   0  fire_images
# 2  fire_images/fire.157.png   0  fire_images
# 3   fire_images/fire.26.png   0  fire_images
# 4  fire_images/fire.314.png   0  fire_images

# %% [markdown]
# ### IMAGE PREPROCESSING

# %%
#masking function
def create_mask_for_plant(image):
    image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    lower_hsv = np.array([0,0,250])
    upper_hsv = np.array([250,255,255])
    
    mask = cv2.inRange(image_hsv, lower_hsv, upper_hsv)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11,11))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    
    return mask

#image segmentation function
def segment_image(image):
    mask = create_mask_for_plant(image)
    output = cv2.bitwise_and(image, image, mask = mask)
    return output/255

#sharpen the image
def sharpen_image(image):
    image_blurred = cv2.GaussianBlur(image, (0, 0), 3)
    image_sharp = cv2.addWeighted(image, 1.5, image_blurred, -0.5, 0)
    return image_sharp

# function to get an image
def read_img(filepath, size):
    img = image.load_img(os.path.join(data_folder, filepath), target_size=size)
    #convert image to array
    img = image.img_to_array(img)
    return img

# %% [markdown]
# ### SHOW SAMPLE IMAGES

# %%
nb_rows = 3
nb_cols = 5
fig, axs = plt.subplots(nb_rows, nb_cols, figsize=(10, 5));
plt.suptitle('SAMPLE IMAGES');
for i in range(0, nb_rows):
    for j in range(0, nb_cols):
        axs[i, j].xaxis.set_ticklabels([]);
        axs[i, j].yaxis.set_ticklabels([]);
        axs[i, j].imshow((read_img(df['file'][np.random.randint(1000)], (255,255)))/255.);
plt.show();

# %% [markdown]
# ### SHOW SAMPLE PROCESSED IMAGE

# %%
#get an image
img = read_img(df['file'][102],(255,255))
#mask
image_mask = create_mask_for_plant(img)
#segmentation
image_segmented = segment_image(img)
#sharpen the image
image_sharpen = sharpen_image(image_segmented)

fig, ax = plt.subplots(1, 4, figsize=(10, 5));
plt.suptitle('SAMPLE PROCESSED IMAGE', x=0.5, y=0.8)
plt.tight_layout(1)

ax[0].set_title('ORIG.', fontsize=12)
ax[1].set_title('MASK', fontsize=12)
ax[2].set_title('SEGMENTED', fontsize=12)
ax[3].set_title('SHARPEN', fontsize=12)


ax[0].imshow(img/255);
ax[1].imshow(image_mask);
ax[2].imshow(image_segmented);
ax[3].imshow(image_sharpen);

# %% [markdown]
# ### XCEPTION BOTTLENECK FEATURE EXTRACTION

# %%
INPUT_SIZE=255

##preprocess the input
X_train = np.zeros((len(df), INPUT_SIZE, INPUT_SIZE, df.shape[1]), dtype='float')
for i, file in tqdm(enumerate(df['file'])):
    #read image
    img = read_img(file,(INPUT_SIZE,INPUT_SIZE))
    #masking and segmentation
    image_segmented = segment_image(img)
    #sharpen
    image_sharpen = sharpen_image(image_segmented)
    x = xception.preprocess_input(np.expand_dims(image_sharpen.copy(), axis=0))
    X_train[i] = x
# Out:
# 999it [01:21, 12.22it/s]

# %%
print('Train Image Shape: ', X_train.shape)
print('Train Image Size: ', X_train.size)
# Out:
# Train Image Shape:  (999, 255, 255, 3)
# Train Image Size:  194879925

# %% [markdown]
# #### SPLIT THE DATA

# %%
y = df['id']
train_x, train_val, y_train, y_val = train_test_split(X_train, y, test_size=0.2, random_state=101)

# %%
print('FIRE IMAGES ON TRAINING DATA: ',y_train[y_train==0].shape[0])
print('NON-FIRE IMAGES ON TRAINING DATA: ',y_train[y_train==1].shape[0])
# Out:
# FIRE IMAGES ON TRAINING DATA:  610
# NON-FIRE IMAGES ON TRAINING DATA:  189

# %%
##get the features
xception_bf = xception.Xception(weights='imagenet', include_top=False, pooling='avg')
bf_train_x = xception_bf.predict(train_x, batch_size=32, verbose=1)
bf_train_val = xception_bf.predict(train_val, batch_size=32, verbose=1)
# Out:
# 25/25 [==============================] - 3s 109ms/step
# 7/7 [==============================] - 1s 96ms/step

# %%
#print shape of feature and size
print('Train Shape: ', bf_train_x.shape)
print('Train Size: ', bf_train_x.size)

print('Validation Shape: ', bf_train_val.shape)
print('Validation Size: ', bf_train_val.size)
# Out:
# Train Shape:  (799, 2048)
# Train Size:  1636352
# Validation Shape:  (200, 2048)
# Validation Size:  409600

# %% [markdown]
# ### DEEP LEARNING MODEL

# %%
#keras Sequential model
model = Sequential()
model.add(Dense(units = 256 , activation = 'relu', input_dim=bf_train_x.shape[1]))
model.add(Dense(units = 64 , activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))
model.compile(optimizer = 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 541,057
# Trainable params: 541,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model @ 100 epochs
history = model.fit(bf_train_x, y_train, epochs=100, batch_size=32);
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5476 - accuracy: 0.7635
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4812 - accuracy: 0.7635
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4158 - accuracy: 0.7960
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.8123
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8436
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3189 - accuracy: 0.8673
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3094 - accuracy: 0.8573
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2861 - accuracy: 0.8761
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2776 - accuracy: 0.8736
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8423
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8748
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2608 - accuracy: 0.8911
# Epoch 13/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.9074
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2257 - accuracy: 0.9074
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2413 - accuracy: 0.8949
# Epoch 16/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2755 - accuracy: 0.8736
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.8874
# Epoch 18/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2192 - accuracy: 0.9086
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2099 - accuracy: 0.9186
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2298 - accuracy: 0.8999
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1990 - accuracy: 0.9136
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1995 - accuracy: 0.9174
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1839 - accuracy: 0.9337
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.9061
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1782 - accuracy: 0.9262
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1807 - accuracy: 0.9212
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.9199
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2090 - accuracy: 0.9024
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.9312
# Epoch 30/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1673 - accuracy: 0.9312
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.9374
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.9174
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2245 - accuracy: 0.8974
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2025 - accuracy: 0.9086
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.9186
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1583 - accuracy: 0.9349
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1556 - accuracy: 0.9349
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1513 - accuracy: 0.9349
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1696 - accuracy: 0.9337
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1635 - accuracy: 0.9299
# Epoch 41/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1572 - accuracy: 0.9374
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1555 - accuracy: 0.9362
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1613 - accuracy: 0.9262
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1639 - accuracy: 0.9299
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1523 - accuracy: 0.9362
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1515 - accuracy: 0.9349
# Epoch 47/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1366 - accuracy: 0.9437
# Epoch 48/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1448 - accuracy: 0.9337
# Epoch 49/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1854 - accuracy: 0.9136
# Epoch 50/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1331 - accuracy: 0.9474
# Epoch 51/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1288 - accuracy: 0.9462
# Epoch 52/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.9437
# Epoch 53/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.9524
# Epoch 54/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.9474
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1400 - accuracy: 0.9349
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1184 - accuracy: 0.9574
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1164 - accuracy: 0.9499
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9399
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1499 - accuracy: 0.9399
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1301 - accuracy: 0.9437
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1278 - accuracy: 0.9399
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1648 - accuracy: 0.9287
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.9212
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1188 - accuracy: 0.9499
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9562
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1110 - accuracy: 0.9549
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1906 - accuracy: 0.9099
# Epoch 68/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9337
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1096 - accuracy: 0.9537
# Epoch 70/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.9612
# Epoch 71/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1143 - accuracy: 0.9599
# Epoch 72/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.9512
# Epoch 73/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.9562
# Epoch 74/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.1085 - accuracy: 0.9562
# Epoch 75/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1004 - accuracy: 0.9549
# Epoch 76/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1091 - accuracy: 0.9562
# Epoch 77/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 0.9574
# Epoch 78/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1161 - accuracy: 0.9462
# Epoch 79/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1071 - accuracy: 0.9474
# Epoch 80/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0976 - accuracy: 0.9587
# Epoch 81/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1119 - accuracy: 0.9549
# Epoch 82/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1175 - accuracy: 0.9599
# Epoch 83/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1387 - accuracy: 0.9324
# Epoch 84/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1718 - accuracy: 0.9111
# Epoch 85/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1560 - accuracy: 0.9262
# Epoch 86/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1086 - accuracy: 0.9512
# Epoch 87/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1006 - accuracy: 0.9537
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.9537
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1159 - accuracy: 0.9599
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9462
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 0.9599
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1094 - accuracy: 0.9612
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9562
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1094 - accuracy: 0.9574
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9474
# Epoch 96/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9524
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9499
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0983 - accuracy: 0.9637
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0951 - accuracy: 0.9662
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9637

# %% [markdown]
# #### LOSS AND ACCURACY

# %%
fig, ax = plt.subplots(1,2,figsize=(14,5))
ax[0].set_title('TRAINING LOSS');
ax[1].set_title('TRAINING ACCURACY');


ax[0].plot(history.history['loss'], color= 'salmon',lw=2);
ax[1].plot(history.history['accuracy'], color= 'green',lw=2);

# %%
#predict the validation data
predictions = model.predict_classes(bf_train_val)

# %% [markdown]
# #### CLASSIFICATION REPORT

# %%
print(classification_report(y_val, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       145
#            1       0.84      0.85      0.85        55
#
#     accuracy                           0.92       200
#    macro avg       0.89      0.90      0.89       200
# weighted avg       0.92      0.92      0.92       200

# %% [markdown]
# #### CONFUSION MATRIX

# %%
confusion_mat = confusion_matrix(y_val, predictions)

plt.figure(figsize=(10,10))
sns.heatmap(confusion_mat, square=True, annot=True,
            yticklabels=['FIRE_IMG', 'NON_FIRE_IMG'],
            xticklabels=['FIRE_IMG', 'NON_FIRE_IMG']);
plt.title('CONFUSION MATRIX');
plt.xlabel('Y_TRUE');
plt.ylabel("PREDICTIONS");
